# %%
import os

os.chdir(r"C:\Users\DELL\OneDrive\Desktop\Academics\3rd Year\5th Sem\Academic Related Docs\Junaid's Intership Tasks\Task 01")

print("Current Folder:", os.getcwd())
# Out:
# Current Folder: C:\Users\DELL\OneDrive\Desktop\Academics\3rd Year\5th Sem\Academic Related Docs\Junaid's Intership Tasks\Task 01

# %%
import pandas as pd

df = pd.read_csv("student-mat.csv", sep=';')
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.head()

print("Missing Values in Each Column:")
print(df.isnull().sum())

print("\nData Types of Each Column:")
print(df.dtypes)

print("\nShape of the Dataset (rows, columns):")
print(df.shape)
# Out:
# Missing Values in Each Column:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64
#
# Data Types of Each Column:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# ...

# %%
print("Duplicate rows before cleaning:", df.duplicated().sum())

df = df.drop_duplicates()

print("Duplicate rows after cleaning:", df.duplicated().sum())

print("Final shape of the dataset:", df.shape)
# Out:
# Duplicate rows before cleaning: 0
# Duplicate rows after cleaning: 0
# Final shape of the dataset: (395, 33)

# %%
average_g3 = df["G3"].mean()
print("1. Average Final Grade (G3):", average_g3)

above_15_count = df[df["G3"] > 15].shape[0]
print("2. Students scoring above 15 in G3:", above_15_count)

correlation = df["studytime"].corr(df["G3"])
print("3. Correlation between Study Time and G3:", correlation)

gender_avg = df.groupby("sex")["G3"].mean()
print("4. Average G3 by Gender:\n", gender_avg)
# Out:
# 1. Average Final Grade (G3): 10.415189873417722
# 2. Students scoring above 15 in G3: 40
# 3. Correlation between Study Time and G3: 0.0978196896531963
# 4. Average G3 by Gender:
#  sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
plt.hist(df['G3'], bins=10, color='orchid', edgecolor='black')
plt.title("Distribution of Final Grades (G3)")
plt.xlabel("Final Grade (G3)")
plt.ylabel("Number of Students")
plt.grid(True)
plt.show()

plt.figure(figsize=(8,5))
sns.scatterplot(x="studytime", y="G3", data=df)
plt.title("Study Time vs Final Grade")
plt.xlabel("Study Time (Weekly)")
plt.ylabel("Final Grade (G3)")
plt.grid(True)
plt.show()

plt.figure(figsize=(6,5))
sns.barplot(x="sex", y="G3", data=gender_avg, hue="sex", palette="pastel", legend=False)
plt.title("Average Final Grade by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Final Grade (G3)")
plt.grid(True)
plt.show()

# %% [markdown]
# # Final Summary and Understanding
#
# So, this was my first time doing anything like data analysis or using Python for such work.
# I had no idea how this stuff worked when I started, but I slowly figured things out step by step with patience.
#
# ---
#
# ## Step 1: Loading the Data
#
# I used a dataset called `student-mat.csv`. It had data of 395 students and different information about them like their study time, grades, gender, etc.
#
# I loaded it using pandas and checked the first few rows to make sure it worked properly.
#
# ---
#
# ## Step 2: Exploring the Data
#
# I checked if there were any missing values in the file, but luckily there were none.
# Then I checked the type of data in each column and found that some were numbers (like grades) and some were text (like gender and school).
# The dataset had 395 rows and 33 columns.
#
# ---
#
# ## Step 3: Cleaning the Data
#
# I checked for duplicate rows and there were also none, so I didn’t have to clean much.
# Basically, the data was already clean and well-structured.
#
# ---
#
# ## Step 4: Data Analysis
#
# Then I did some analysis to answer a few questions:
#
# 1. Average final grade (G3): Around 10.41
# 2. Number of students who scored above 15 in G3: 40 students
# 3. Study time and final grade correlation: Around 0.09, which means there's only a small connection
# 4. Who scored more (on average) — boys or girls?
#    - Girls: ~9.96
#    - Boys: ~10.91
#    So, in this dataset, boys had slightly higher grades.
#
# ---
#
# ## Step 5: Visualizations
#
# This part was fun. I made 3 graphs:
#
# - A histogram showing that most students scored between 8 and 12 in the final grade.
# - A scatter plot to show if more study time meant better grades. It was not a strong link.
# - A bar chart comparing boys and girls. It showed boys slightly ahead on average.
#
# ---
#
# ## Final Thoughts
#
# To be honest, I was completely new to this and had no experience with data or Python.
# But I learned how to:
# - Open and explore data using pandas
# - Clean and prepare data
# - Answer questions using code
# - Make graphs using matplotlib and seaborn
#
# I was blank at the start, but once I understood what each step meant, it started making sense.
# Now I feel more confident working with data like this.
